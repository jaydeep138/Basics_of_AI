# %% [markdown]
# <a href="https://colab.research.google.com/github/jaydeep138/Basics_of_AI/blob/main/Fashion_MNIST_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

data = tf.keras.datasets.mnist

(training_images, training_labels), (testing_images, testing_labels) = data.load_data()

training_images = training_images.reshape(60000, 28, 28, 1)
training_images = training_images / 255.0
testing_images = testing_images.reshape(10000, 28, 28, 1)
testing_images = testing_images / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu', input_shape = (28,28,1)),
    tf.keras.layers.MaxPool2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
    tf.keras.layers.MaxPool2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = tf.nn.relu),
    tf.keras.layers.Dense(10, activation = tf.nn.softmax)
])

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(training_images, training_labels, epochs = 50)
model.evaluate(testing_images, testing_labels)

classifications = model.predict(testing_images)

print(classifications[0])
print(testing_labels[0])
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 90s 47ms/step - loss: 0.1187 - accuracy: 0.9627
# Epoch 2/50
# 1875/1875 [==============================] - 87s 47ms/step - loss: 0.0403 - accuracy: 0.9874
# Epoch 3/50
# 1875/1875 [==============================] - 87s 46ms/step - loss: 0.0266 - accuracy: 0.9911
# Epoch 4/50
# 1875/1875 [==============================] - 87s 46ms/step - loss: 0.0197 - accuracy: 0.9936
# Epoch 5/50
# 1875/1875 [==============================] - 86s 46ms/step - loss: 0.0152 - accuracy: 0.9952
# Epoch 6/50
# 1875/1875 [==============================] - 86s 46ms/step - loss: 0.0114 - accuracy: 0.9964
# Epoch 7/50
# 1875/1875 [==============================] - 87s 46ms/step - loss: 0.0090 - accuracy: 0.9970
# Epoch 8/50
# 1875/1875 [==============================] - 87s 46ms/step - loss: 0.0084 - accuracy: 0.9971
# Epoch 9/50
# 1875/1875 [==============================] - 86s 46ms/step - loss: 0.0067 - accuracy: 0.9976
# Epoch 10/50
# ...
